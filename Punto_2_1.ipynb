# %% [markdown]
# <a href="https://colab.research.google.com/github/felipe24I/Parcial-2/blob/main/Punto_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Solución teórica**

# %% [markdown]
# ![WhatsApp Image 2023-10-26 at 10.31.58 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.1 pag2.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.1 pag3.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.1 pag4.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.1 pag5.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.1 pag6.jpeg](data:image/jpeg;base64,...)
